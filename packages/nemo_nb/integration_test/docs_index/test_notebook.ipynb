# %% [markdown]
# # Test Notebook
#
# This notebook tests directive support.
#
# ## Tab-Set Example
#
# ::::{tab-set}
# :::{tab-item} Python
#
# Python code example:
#
# :::
#
# :::{tab-item} Bash
#
# Bash code example:
#
# :::
# ::::

# %%
# Python code
x = 1
y = 2
print(f"Sum: {x + y}")

# %% [markdown]
# ## Dropdown Example
#
# :::{dropdown} Click to expand
# Hidden content here!
# :::

# %%
# Bash code wrapped in Python comment for linting
# echo 'Hello from bash'
import subprocess

subprocess.run(["echo", "Hello from bash"])

# %%
# This cell should be hidden
secret = "should not appear"
